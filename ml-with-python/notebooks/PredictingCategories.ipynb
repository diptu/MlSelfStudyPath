# %%
import sys
from types import ModuleType
# !pip3 install seaborn
# Create a mock module in memory
m = ModuleType("mlwpy")
m.__dict__.update({
    'np': __import__('numpy'),
    'pd': __import__('pandas'),
    'plt': __import__('matplotlib.pyplot'),
    'sns': __import__('seaborn'),
    'os': __import__('os'),
    'sys': __import__('sys'),
})

# Add it to the system modules so 'import' can find it
sys.modules["mlwpy"] = m

print("mlwpy helper initialized.")
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy!=1.24.0,>=1.20 (from seaborn)
#   Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting pandas>=1.2 (from seaborn)
#   Using cached pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (118 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/macbook/Project/personal/MlSelfStudyPath/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/macbook/Project/personal/MlSelfStudyPath/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/macbook/Project/personal/MlSelfStudyPath/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.1 MB/s  0:00:00m 3.1 MB/s eta 0:00:01
# Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
# Using cached pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
# Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [seaborn]━  9/10 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.4 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 10
#       6 m.__dict__.update({
#       7     'np': __import__('numpy'),
#       8     'pd': __import__('pandas'),
#       9     'plt': __import__('matplotlib.pyplot'),
# ---> 10     'sns': __import__('seaborn'),
#      11     'os': __import__('os'),
#      12     'sys': __import__('sys'),
#      13 })
#
# ModuleNotFoundError: No module named 'seaborn'
